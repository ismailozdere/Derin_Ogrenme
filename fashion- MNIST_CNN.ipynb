# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
# !pip install keras

# %%
from __future__ import print_function
import keras 
from keras.datasets import fashion_mnist
from keras.models import load_model
import os 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline 

import random

# %% [markdown]
# **verilerin internet üzerinden çekilmesi**

# %%
(x_train , y_train ) , ( x_test , y_test) = fashion_mnist.load_data()

print("x_train shape : " ,x_train.shape)
print(x_train.shape[0] , "test örnekleri")
print(x_test.shape[0] , "test örnekleri")

print(x_train.shape , y_train.shape)
print(x_test.shape , y_test.shape)
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step
# x_train shape :  (60000, 28, 28)
# 60000 test örnekleri
# 10000 test örnekleri
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# Verilerin içinden örnek görelim

# %%
plt.imshow(x_train[100] , cmap="gray")

# %% [markdown]
# 10 sınıftan oluşan Fashion MNIST veri kümelerinde sınıf adlandıralım

# %%
fashion_mnist_labels = np.array([
                                 "Tişört/Üst",
                                 "Pantolon",
                                 "Kazak",
                                 "elbise",
                                 "ceket",
                                 "sandalet",
                                 "gömlek",
                                 "sneaker",
                                 "çanta",
                                 "bilekte bot" ])
