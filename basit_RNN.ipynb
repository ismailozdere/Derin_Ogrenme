# %% [markdown]
# # Basit bir Yinelemeli Sinir Ağını Numpy ile Oluşturmak

# %%
import numpy as np

# %% [markdown]
#
#
# *   ***timesteps*** --> girişteki zaman adımı sayısı
# *   ***input_features*** -->  girdi nitelik uzayını boyutu
# *   ***output_features*** --> çıktı nitelik uzayının boyutu

# %%
timesteps = 100 
input_features = 32 
output_features = 64

# %% [markdown]
# Basit olması için girdi verisini rasgele gürültü olarak seçelim

# %%
inputs = np.random.random((timesteps , input_features))

# %% [markdown]
# Başlangıç ddurumu için tüm elemanları sıfırdan oluşan bir vektör oluşturalım

# %%
state_t = np.zeros((output_features , ))

# %% [markdown]
# Rasgele oluşturulan ağırlık matrisleri

# %%
W = np.random.random((output_features , input_features))
U = np.random.random((output_features , output_features))
b = np.random.random((output_features , ))

# %% [markdown]
# # ***Girdi ve mevcut duruma göre çıktının oluştrulması***

# %%
successive_outputs = []
for input_t in inputs:
  output_t = np.tanh(np.dot(W , input_t) + np.dot(U , state_t) + b)
  successive_outputs.append(output_t)
  state_t = output_features

final_output_sequence = np.concatenate( successive_outputs , axis = 0 )

# %%
output_t = np.tanh( np.dot(W , input_t) + np.dot( U , state_t) + b)
