# %% [markdown]
# Kimlik doğrulama

# %%
from google.colab import drive
drive.mount("/gdrive")
# %cd / gdrive
# Out:
# Mounted at /gdrive
# [Errno 2] No such file or directory: '/ gdrive'
# /content

# %% [markdown]
# # Kütüphane kurulumları ve ağların oluşturulması

# %%
from keras import Input , layers

# %%
input_tensor = Input((32 , ) )
dense  = layers.Dense(32 , activation= "relu")
output_tensor = dense(input_tensor)

# %%
from keras.models import Sequential ,Model

# %% [markdown]
# ## Sequantial Model

# %%
seq_model = Sequential()
seq_model.add(layers.Dense(32 , activation= "relu" , input_shape  = (64, )))
seq_model.add(layers.Dense(32 ,  activation= "relu"))
seq_model.add(layers.Dense(10 ,  activation= "softmax"))

seq_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# =================================================================
# Total params: 3,466
# Trainable params: 3,466
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###  ``` functional  ``` Model

# %%
input_tensor = Input(shape = 64 , )

x = layers.Dense(32 , activation= "relu" )(input_tensor)

x = layers.Dense(32 , activation= "relu")(x)

output_tensor = layers.Dense(10 , activation= "softmax")(x)

model = Model(input_tensor , output_tensor)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 64)]              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                330
# =================================================================
# Total params: 3,466
# Trainable params: 3,466
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Modelin Derlenmesi

# %%
model.compile(optimizer= "rmsprop" , loss= "categorical_crossentropy")

# %% [markdown]
# Eğitim için rasgele bir küme oluşturmak

# %%
import numpy as np

# %%
x_train = np.random.random((1000 , 64))
y_train = np.random.random((1000 , 10))

# %% [markdown]
# ## Modelin Eğitilmesi

# %%
model.fit(x_train , y_train , epochs= 10 , batch_size= 128)

score = model.evaluate(x_train , y_train)
# Out:
# Epoch 1/10
# 8/8 [==============================] - 15s 4ms/step - loss: 11.9505
# Epoch 2/10
# 8/8 [==============================] - 0s 3ms/step - loss: 13.6177
# Epoch 3/10
# 8/8 [==============================] - 0s 3ms/step - loss: 16.2684
# Epoch 4/10
# 8/8 [==============================] - 0s 3ms/step - loss: 19.5594
# Epoch 5/10
# 8/8 [==============================] - 0s 3ms/step - loss: 22.7004
# Epoch 6/10
# 8/8 [==============================] - 0s 3ms/step - loss: 26.8625
# Epoch 7/10
# 8/8 [==============================] - 0s 3ms/step - loss: 31.6645
# Epoch 8/10
# 8/8 [==============================] - 0s 4ms/step - loss: 37.6763
# Epoch 9/10
# 8/8 [==============================] - 0s 3ms/step - loss: 43.3969
# Epoch 10/10
# 8/8 [==============================] - 0s 3ms/step - loss: 50.2159
# 32/32 [==============================] - 1s 2ms/step - loss: 55.6106
